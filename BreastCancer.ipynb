# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import seaborn as sns

# %% [markdown]
# Load Dataset

# %%
data=pd.read_csv('/content/data (1).csv')

# %%
# Display first five entries of data
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
# Display last five entries of data

data.tail()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
# ...

# %%
# Display random numbers of data

data.sample(10)
# Out:
#           id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 113   864292         B       10.510         20.19           68.64      334.2
# 316   894090         B       12.180         14.08           77.25      461.4
# 366  9011494         M       20.200         26.83          133.70     1234.0
# 529   918465         B       12.070         13.44           77.83      445.2
# 430   907914         M       14.900         22.53          102.10      685.0
# 501    91504         M       13.820         24.49           92.33      595.9
# 505   915276         B        9.676         13.14           64.12      272.5
# 199   877500         M       14.450         20.22           94.49      642.7
# 50    857343         B       11.760         21.60           74.72      427.9
# 458  9112594         B       13.000         25.13           82.61      520.2
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
data['Unnamed: 32'] = (data['Unnamed: 32'] =='NaN').astype(int)
data['diagnosis'] = (data['diagnosis'] !='M').astype(float)
data
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      842302        1.0        17.99         10.38          122.80
# 1      842517        1.0        20.57         17.77          132.90
# 2    84300903        1.0        19.69         21.25          130.00
# 3    84348301        1.0        11.42         20.38           77.58
# 4    84358402        1.0        20.29         14.34          135.10
# ..        ...        ...          ...           ...             ...
# 564    926424        1.0        21.56         22.39          142.00
# 565    926682        1.0        20.13         28.25          131.20
# 566    926954        1.0        16.60         28.08          108.30
# 567    927241        1.0        20.60         29.33          140.10
# 568     92751        1.0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# ...

# %%
#Count to the null value
data.isnull().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
# Show the information of data to find any null value

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    int64
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
# Show the statistical summary of data

data.describe()
# Out:
#                  id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# count  5.690000e+02      569.0   569.000000    569.000000      569.000000
# mean   3.037183e+07        1.0    14.127292     19.289649       91.969033
# std    1.250206e+08        0.0     3.524049      4.301036       24.298981
# min    8.670000e+03        1.0     6.981000      9.710000       43.790000
# 25%    8.692180e+05        1.0    11.700000     16.170000       75.170000
# 50%    9.060240e+05        1.0    13.370000     18.840000       86.240000
# 75%    8.813129e+06        1.0    15.780000     21.800000      104.100000
# max    9.113205e+08        1.0    28.110000     39.280000      188.500000
#
#          area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# count   569.000000       569.000000        569.000000      569.000000
# mean    654.889104         0.096360          0.104341        0.088799
# std     351.914129         0.014064          0.052813        0.079720
# ...

# %%
data['Unnamed: 32'].value_counts()
# Out:
# Unnamed: 32
# 0    569
# Name: count, dtype: int64

# %%
data.drop(['diagnosis'],axis=1)
# Out:
#            id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302        17.99         10.38          122.80     1001.0
# 1      842517        20.57         17.77          132.90     1326.0
# 2    84300903        19.69         21.25          130.00     1203.0
# 3    84348301        11.42         20.38           77.58      386.1
# 4    84358402        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564    926424        21.56         22.39          142.00     1479.0
# 565    926682        20.13         28.25          131.20     1261.0
# 566    926954        16.60         28.08          108.30      858.1
# 567    927241        20.60         29.33          140.10     1265.0
# 568     92751         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
# Show correlation between columns
data.corr()
data
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      842302        1.0        17.99         10.38          122.80
# 1      842517        1.0        20.57         17.77          132.90
# 2    84300903        1.0        19.69         21.25          130.00
# 3    84348301        1.0        11.42         20.38           77.58
# 4    84358402        1.0        20.29         14.34          135.10
# ..        ...        ...          ...           ...             ...
# 564    926424        1.0        21.56         22.39          142.00
# 565    926682        1.0        20.13         28.25          131.20
# 566    926954        1.0        16.60         28.08          108.30
# 567    927241        1.0        20.60         29.33          140.10
# 568     92751        1.0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# ...

# %% [markdown]
# Check no. of zero values in different columns

# %%
print('Number of zero values in diagnosis',data[data['diagnosis']==0].shape[0])
# Out:
# Number of zero values in diagnosis 0

# %%
print('Number of zero values in texture_mean	',data[data['texture_mean']==0].shape[0])
# Out:
# Number of zero values in texture_mean	 0

# %%
print('Number of zero values in radius_mean',data[data['radius_mean']==0].shape[0])
# Out:
# Number of zero values in radius_mean 0

# %%
print('Number of zero values in area_mean',data[data['area_mean']==0].shape[0])
# Out:
# Number of zero values in area_mean 0

# %% [markdown]
# Data Visualization

# %%
# Histogram of columns

data.hist(bins=20,figsize=(30,30))
plt.show()

# %%
corrmat=data.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(100,100))

#plot heat map

sns.heatmap(data[top_corr_features].corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Split data into x & y

# %%
target_name='Unnamed: 32'

# Separate object for target feature
y = data[target_name]

# Separate object for input feature
x = data.drop(target_name, axis=1)

# %%
x.head()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302        1.0        17.99         10.38          122.80     1001.0
# 1    842517        1.0        20.57         17.77          132.90     1326.0
# 2  84300903        1.0        19.69         21.25          130.00     1203.0
# 3  84348301        1.0        11.42         20.38           77.58      386.1
# 4  84358402        1.0        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Unnamed: 32, dtype: int64

# %% [markdown]
# Train Test Split data

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=1)

# %%
x_train
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 249    884689        1.0        11.52         14.93           73.87
# 58     857810        1.0        13.05         19.31           82.61
# 476    911654        1.0        14.20         20.53           92.41
# 529    918465        1.0        12.07         13.44           77.83
# 422    906616        1.0        11.61         16.02           75.46
# ..        ...        ...          ...           ...             ...
# 129    866674        1.0        19.79         25.12          130.40
# 144    869254        1.0        10.75         14.97           68.26
# 72     859717        1.0        17.20         24.52          114.20
# 235  88249602        1.0        14.03         21.25           89.79
# 37     854941        1.0        13.03         18.42           82.61
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 249      406.3          0.10130           0.07808        0.043280
# ...

# %%
y_train
# Out:
# 249    0
# 58     0
# 476    0
# 529    0
# 422    0
#       ..
# 129    0
# 144    0
# 72     0
# 235    0
# 37     0
# Name: Unnamed: 32, Length: 398, dtype: int64

# %%
x_test
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 421    906564        1.0        14.69         13.98           98.22
# 47      85715        1.0        13.17         18.66           85.98
# 292    891670        1.0        12.95         16.02           83.14
# 186    874217        1.0        18.31         18.58          118.60
# 414    905680        1.0        15.13         29.81           96.71
# ..        ...        ...          ...           ...             ...
# 6      844359        1.0        18.25         19.98          119.60
# 487    913505        1.0        19.44         18.82          128.10
# 11   84610002        1.0        15.78         17.89          103.60
# 268   8910506        1.0        12.87         16.21           82.38
# 419    906290        1.0        11.16         21.41           70.95
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 421      656.1          0.10310           0.18360        0.145000
# ...

# %%
y_test
# Out:
# 421    0
# 47     0
# 292    0
# 186    0
# 414    0
#       ..
# 6      0
# 487    0
# 11     0
# 268    0
# 419    0
# Name: Unnamed: 32, Length: 171, dtype: int64

# %% [markdown]
# Different Classification Algorithms

# %%
from sklearn. ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
print("Train Accuracy of Random Forest Algorithm ", rf.score(x_train,y_train)*100)
print("Test Accuracy score of Random Forest Algorithm ", rf.score(x_test,y_test)*100)
# Out:
# Train Accuracy of Random Forest Algorithm  100.0
# Test Accuracy score of Random Forest Algorithm  100.0

# %%
prediction = rf.predict([["50","2","168","62","110","80","1","1","0","0","1","50",
                          "2","168","62","110","80","1","1","0","0","1","50","2","168","62","110","80","1","1","0","0"]])
if(prediction !=0):
  print("The person has Breast Cancer  disease")
else:
  print("The person has no Breast Cancer disease")
# Out:
# The person has no Breast Cancer disease
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Decision Tree Algorithm

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
print("Train Accuracy of Decision Tree Algorithm ", dt.score(x_train,y_train)*100)
print("Test Accuracy score of Decision Tree Algorithm ", dt.score(x_test,y_test)*100)
# Out:
# Train Accuracy of Decision Tree Algorithm  100.0
# Test Accuracy score of Decision Tree Algorithm  100.0

# %%
prediction = dt.predict([["50","2","168","62","110","80","1","1","0","0","1",
                           "50","2","168","62","110","80","1","1","0","0","1"
                          ,"50","2","168","62","110","80","1","1","0","0"]])
if(prediction !=0):
  print("The person Breast cancer disease")
else:
  print("The person has no Breast Cancer disease")
# Out:
# The person has no Breast Cancer disease
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Logistic Regression Algorithm

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(solver='liblinear', multi_class='ovr')
lr.fit(x_train, y_train)

# %%
print("Train Accuracy of Logistic Regression ", lr.score(x_train,y_train)*100)
print("Test Accuracy score of Logistic Regression ", lr.score(x_test,y_test)*100)

# %% [markdown]
# K-Nearest Neighbor(KNN) Algorithm

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
print("Train Accuracy of KNN Algorithm ", knn.score(x_train,y_train)*100)
print("Test Accuracy score of KNN Algorithm ", knn.score(x_test,y_test)*100)
# Out:
# Train Accuracy of KNN Algorithm  100.0
# Test Accuracy score of KNN Algorithm  100.0

# %%
prediction = dt.predict([["50","2","168","62","110","80","1","1","0","0","1",
                          "50","2","168","62","110","80","1","1","0","0","1",
                          "50","2","168","62","110","80","1","1","0","0"]])
if(prediction ==0):
  print("The person has Breast Cancer disease")
else:
  print("The person has no Breast Cancer disease")
# Out:
# The person has heart disease
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
prediction = dt.predict([["50","2","168","62","110","80","1","1","0","0","1",
                          "50","2","168","62","110","80","1","1","0","0","1",
                          "50","2","168","62","110","80","1","1","0","0"]])
if(prediction !=0):
  print("The person has Breast Cancer disease")
else:
  print("The person has no Breast Cancer disease")
# Out:
# The person has no heart disease
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Predicitng Outcome

# %%
# Prediction on test using random forest

rf_pred = rf.predict(x_test)

# %%
# Prediction on test using decision tree
dt_pred = dt.predict(x_test)

# %%
# Prediction on test using KNN

knn_pred = knn.predict(x_test)

# %% [markdown]
# Confusion Matrix

# %% [markdown]
# Random Forest Algorithm

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve
cm = confusion_matrix(y_test, rf_pred)
print('TN {}'.format(cm[0,0]))
print('FP {}'.format(cm[0,0]))
print('FN {}'.format(cm[0,0]))
print('TP {}'.format(cm[0,0]))
print('Accuracy rate {}'.format(np.divide(np.sum([cm[0,0], cm[0,0]]), np.sum(cm))*100))
print('Misclassification rate {}'.format(np.divide(np.sum([cm[0,0], cm[0,0]]), np.sum(cm))*100))
# Out:
# TN 171
# FP 171
# FN 171
# TP 171
# Accuracy rate 200.0
# Misclassification rate 200.0
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:409: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(

# %%
sns.heatmap(confusion_matrix(y_test, rf_pred), annot=True,fmt="d")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:409: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# <Axes: >

# %% [markdown]
# Decision Tree Algorithm

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve
cm = confusion_matrix(y_test, dt_pred)
print('TN {}'.format(cm[0,0]))
print('FP {}'.format(cm[0,0]))
print('FN {}'.format(cm[0,0]))
print('TP {}'.format(cm[0,0]))
print('Accuracy rate {}'.format(np.divide(np.sum([cm[0,0], cm[0,0]]), np.sum(cm))*100))
print('Misclassification rate {}'.format(np.divide(np.sum([cm[0,0], cm[0,0]]), np.sum(cm))*100))
# Out:
# TN 171
# FP 171
# FN 171
# TP 171
# Accuracy rate 200.0
# Misclassification rate 200.0
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:409: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(

# %%
sns.heatmap(confusion_matrix(y_test, dt_pred), annot=True,fmt="d")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:409: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# <Axes: >

# %% [markdown]
# K-Nearest Neighbor(KNN) Algorithm

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve
cm = confusion_matrix(y_test, knn_pred)

print('TN {}'.format(cm[0,0]))
print('FP {}'.format(cm[0,0]))
print('FN {}'.format(cm[0,0]))
print('TP {}'.format(cm[0,0]))
print('Accuracy rate {}'.format(np.divide(np.sum([cm[0,0], cm[0,0]]), np.sum(cm))*100))
print('Misclassification rate {}'.format(np.divide(np.sum([cm[0,0], cm[0,0]]), np.sum(cm))*100))
# Out:
# TN 171
# FP 171
# FN 171
# TP 171
# Accuracy rate 200.0
# Misclassification rate 200.0
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:409: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(

# %%
sns.heatmap(confusion_matrix(y_test, knn_pred), annot=True,fmt="d")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:409: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# <Axes: >
